# %% [markdown]
# # Julia 機器學習：GLM 線性迴歸

# %% [markdown]
# 本範例需要使用到的套件有 GLM、RDatasets、MLDataUtils，請在執行以下範例前先安裝。
#
# ```
# ] add GLM
# ] add RDatasets
# ] add MLDataUtils
# ```

# %%
using Pkg
Pkg.add(["GLM","MLDataUtils"])
# Out:
#    Updating registry at `C:\Users\ocean_chou\.julia\registries\General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
# ┌ Warning: Some registries failed to update:
# │     — C:\Users\ocean_chou\.julia\registries\General — failed to fetch from repo
# └ @ Pkg.Types D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.4\Pkg\src\Types.jl:1122
#   Resolving package versions...
#   Installed MLDataUtils ─── v0.5.1
#   Installed MLDataPattern ─ v0.5.3
#     Cloning [7f8f8fb0-2700-5f03-b4bd-41f8cfc144b6] LearnBase from https://github.com/JuliaML/LearnBase.jl.git
#     Fetching: [=========>                               ]  21.1 %
#     Fetching: [==================>                      ]  43.6 %
#     Fetching: [============================
# Fetching: [========================================>]  100.0 % ]  94.3 %
#   Installed LearnBase ───── v0.3.0
#     Cloning [66a33bbf-0c2b-5fc8-a008-9da813334f0a] MLLabelUtils from https://github.com/JuliaML/MLLabelUtils.jl.git
#     Fetching: [
#     Fetching:
#     Fetching: [========================>
#     Fetching:
# Fetching: [========================================>]  100.0 %  99.8 %
#   Installed MLLabelUtils ── v0.5.2
#     Cloning [38e38edf-8417-5370-95a0-9cbb8c7f171a] GLM from https://github.com/JuliaStats/GLM.jl.git
# ching: [========================================>]  100.0 %Fetching: [===========>                             ]  25.5 %                       ]  40.5 %                    ]  49.0 %==========================>              ]  64.1 %79.0 %================================>        ]  79.8 %94.7 %
#   Installed GLM ─────────── v1.3.9
#     Cloning [dbb5928d-eab1-5f90-85c2-b9b0edb7c900] MappedArrays from https://github.com/JuliaArrays/MappedArrays.jl.git
#     Fetching: [=====================>
# Fetching: [========================================>]  100.0 %
#   Installed MappedArrays ── v0.2.2
#    Updating `C:\Users\ocean_chou\.julia\environments\v1.4\Project.toml`
#   [38e38edf] + GLM v1.3.9
#   [cc2ba9b6] + MLDataUtils v0.5.1
#    Updating `C:\Users\ocean_chou\.julia\environments\v1.4\Manifest.toml`
#   [38e38edf] + GLM v1.3.9
#   [7f8f8fb0] + LearnBase v0.3.0
#   [9920b226] + MLDataPattern v0.5.3
#   [cc2ba9b6] + MLDataUtils v0.5.1
#   [66a33bbf] + MLLabelUtils v0.5.2
#   [dbb5928d] + MappedArrays v0.2.2

# %%
using GLM
using RDatasets
using MLDataUtils
using Statistics
# Out:
# ┌ Info: Precompiling GLM [38e38edf-8417-5370-95a0-9cbb8c7f171a]
# └ @ Base loading.jl:1260
# ┌ Info: Precompiling RDatasets [ce6b1742-4840-55fa-b093-852dadbb1d8b]
# └ @ Base loading.jl:1260
# ┌ Info: Precompiling MLDataUtils [cc2ba9b6-d476-5e6d-8eaf-a92d5412d41d]
# └ @ Base loading.jl:1260

# %% [markdown]
# ## 單純線性迴歸模型示範

# %% [markdown]
# ## 載入資料

# %%
data = RDatasets.dataset("datasets", "longley")
# Out:
# 16×8 DataFrame. Omitted printing of 2 columns
# │ Row │ Year  │ GNPDeflator │ GNP     │ Unemployed │ ArmedForces │ Population │
# │     │ Int64 │ Float64     │ Float64 │ Float64    │ Float64     │ Float64    │
# ├─────┼───────┼─────────────┼─────────┼────────────┼─────────────┼────────────┤
# │ 1   │ 1947  │ 83.0        │ 234.289 │ 235.6      │ 159.0       │ 107.608    │
# │ 2   │ 1948  │ 88.5        │ 259.426 │ 232.5      │ 145.6       │ 108.632    │
# │ 3   │ 1949  │ 88.2        │ 258.054 │ 368.2      │ 161.6       │ 109.773    │
# │ 4   │ 1950  │ 89.5        │ 284.599 │ 335.1      │ 165.0       │ 110.929    │
# │ 5   │ 1951  │ 96.2        │ 328.975 │ 209.9      │ 309.9       │ 112.075    │
# │ 6   │ 1952  │ 98.1        │ 346.999 │ 193.2      │ 359.4       │ 113.27     │
# │ 7   │ 1953  │ 99.0        │ 365.385 │ 187.0      │ 354.7       │ 115.094    │
# │ 8   │ 1954  │ 100.0       │ 363.112 │ 357.8      │ 335.0       │ 116.219    │
# │ 9   │ 1955  │ 101.2       │ 397.469 │ 290.4      │ 304.8       │ 117.388    │
# │ 10  │ 1956  │ 104.6       │ 419.18  │ 282.2      │ 285.7       │ 118.734    │
# │ 11  │ 1957  │ 108.4       │ 442.769 │ 293.6      │ 279.8       │ 120.445    │
# │ 12  │ 1958  │ 110.8       │ 444.546 │ 468.1      │ 263.7       │ 121.95     │
# │ 13  │ 1959  │ 112.6       │ 482.704 │ 381.3      │ 255.2       │ 123.366    │
# │ 14  │ 1960  │ 114.2       │ 502.601 │ 393.1      │ 251.4       │ 125.368    │
# │ 15  │ 1961  │ 115.7       │ 518.173 │ 480.6      │ 257.2       │ 127.852    │
# │ 16  │ 1962  │ 116.9       │ 554.894 │ 400.7      │ 282.7       │ 130.081    │

# %% [markdown]
# ## 線性迴歸模型

# %%
model = GLM.lm(@formula(Employed ~ GNP), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,LinearAlgebra.Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# Employed ~ 1 + GNP
#
# Coefficients:
# ──────────────────────────────────────────────────────────────────────────────
#                Estimate  Std. Error  t value  Pr(>|t|)   Lower 95%   Upper 95%
# ──────────────────────────────────────────────────────────────────────────────
# (Intercept)  51.8436     0.681372    76.0871    <1e-19  50.3822     53.305
# GNP           0.0347523  0.00170571  20.3741    <1e-11   0.0310939   0.0384107
# ──────────────────────────────────────────────────────────────────────────────

# %%
intercept, slope = coef(model)
# Out:
# 2-element Array{Float64,1}:
#  51.84358978188421
#   0.03475229434762888

# %% [markdown]
# ## 預測

# %%
new_X = DataFrame(GNP=[300., 400., 500.])
# Out:
# 3×1 DataFrame
# │ Row │ GNP     │
# │     │ Float64 │
# ├─────┼─────────┤
# │ 1   │ 300.0   │
# │ 2   │ 400.0   │
# │ 3   │ 500.0   │

# %%
predict(model, new_X)
# Out:
# 3-element Array{Union{Missing, Float64},1}:
#  62.269278086172875
#  65.74450752093577
#  69.21973695569865

# %% [markdown]
# ## 模型評估

# %%
GLM.r2(model)
# Out:
# 0.9673737718541232

# %%
GLM.adjr2(model)
# Out:
# 0.9650433269865606

# %% [markdown]
# ## 多元線性迴歸模型

# %% [markdown]
# ## 載入資料

# %%
data = RDatasets.dataset("datasets", "mtcars")
first(data, 6)
# Out:
# 6×12 DataFrame. Omitted printing of 6 columns
# │ Row │ Model             │ MPG     │ Cyl   │ Disp    │ HP    │ DRat    │
# │     │ String            │ Float64 │ Int64 │ Float64 │ Int64 │ Float64 │
# ├─────┼───────────────────┼─────────┼───────┼─────────┼───────┼─────────┤
# │ 1   │ Mazda RX4         │ 21.0    │ 6     │ 160.0   │ 110   │ 3.9     │
# │ 2   │ Mazda RX4 Wag     │ 21.0    │ 6     │ 160.0   │ 110   │ 3.9     │
# │ 3   │ Datsun 710        │ 22.8    │ 4     │ 108.0   │ 93    │ 3.85    │
# │ 4   │ Hornet 4 Drive    │ 21.4    │ 6     │ 258.0   │ 110   │ 3.08    │
# │ 5   │ Hornet Sportabout │ 18.7    │ 8     │ 360.0   │ 175   │ 3.15    │
# │ 6   │ Valiant           │ 18.1    │ 6     │ 225.0   │ 105   │ 2.76    │

# %% [markdown]
# ## 切分訓練資料及測試資料

# %%
indecies = MLDataUtils.shuffleobs(collect(1:nrow(data)))
train_ind, test_ind = MLDataUtils.splitobs(indecies, at = 0.8);

# %%
train = data[train_ind, :]
test = data[test_ind, :]
# Out:
# 6×12 DataFrame. Omitted printing of 6 columns
# │ Row │ Model             │ MPG     │ Cyl   │ Disp    │ HP    │ DRat    │
# │     │ String            │ Float64 │ Int64 │ Float64 │ Int64 │ Float64 │
# ├─────┼───────────────────┼─────────┼───────┼─────────┼───────┼─────────┤
# │ 1   │ Dodge Challenger  │ 15.5    │ 8     │ 318.0   │ 150   │ 2.76    │
# │ 2   │ Pontiac Firebird  │ 19.2    │ 8     │ 400.0   │ 175   │ 3.08    │
# │ 3   │ Chrysler Imperial │ 14.7    │ 8     │ 440.0   │ 230   │ 3.23    │
# │ 4   │ Camaro Z28        │ 13.3    │ 8     │ 350.0   │ 245   │ 3.73    │
# │ 5   │ Hornet Sportabout │ 18.7    │ 8     │ 360.0   │ 175   │ 3.15    │
# │ 6   │ Fiat X1-9         │ 27.3    │ 4     │ 79.0    │ 66    │ 4.08    │

# %% [markdown]
# ## 線性迴歸模型

# %%
ols = GLM.lm(@formula(MPG ~ Cyl + Disp + HP + DRat + WT + QSec + VS + AM + Gear + Carb), train)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,LinearAlgebra.Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# MPG ~ 1 + Cyl + Disp + HP + DRat + WT + QSec + VS + AM + Gear + Carb
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────────────────
#                 Estimate  Std. Error      t value  Pr(>|t|)    Lower 95%   Upper 95%
# ────────────────────────────────────────────────────────────────────────────────────
# (Intercept)  10.2939      19.7168      0.522089      0.6092  -31.7314     52.3192
# Cyl           0.382505     1.1057      0.345938      0.7342   -1.97425     2.73926
# Disp          0.00907776   0.0200238   0.453349      0.6568   -0.0336019   0.0517575
# HP           -0.025914     0.0243795  -1.06294       0.3046   -0.0778776   0.0260496
# DRat         -0.238469     1.8805     -0.126812      0.9008   -4.24667     3.76973
# WT           -4.53108      2.22377    -2.03757       0.0596   -9.27093     0.20877
# QSec          1.06156      0.796511    1.33276       0.2025   -0.636164    2.75928
# VS            0.51152      2.125       0.240716      0.8130   -4.0178      5.04084
# AM            2.74584      2.22564     1.23373       0.2363   -1.99801     7.48968
# Gear          1.06836      1.64121     0.650956      0.5249   -2.4298      4.56651
# Carb          0.00108398   0.849839    0.00127551    0.9990   -1.81031     1.81247
# ────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## 預測

# %%
predict(ols, test)
# Out:
# 6-element Array{Union{Missing, Float64},1}:
#  16.861713729930415
#  15.600408354107246
#   8.10079916831949
#  11.461400445066946
#  17.02384643139445
#  28.68546411367895

# %% [markdown]
# ## 模型評估

# %%
GLM.r²(ols)
# Out:
# 0.8910087828608781

# %%
GLM.adjr²(ols)
# Out:
# 0.8183479714347969

# %% [markdown]
# ## 羅吉斯迴歸模型示範

# %% [markdown]
# ## 載入資料

# %%
data = RDatasets.dataset("ISLR", "Default")
first(data, 6)
# Out:
# 6×4 DataFrame
# │ Row │ Default      │ Student      │ Balance │ Income  │
# │     │ Categorical… │ Categorical… │ Float64 │ Float64 │
# ├─────┼──────────────┼──────────────┼─────────┼─────────┤
# │ 1   │ No           │ No           │ 729.526 │ 44361.6 │
# │ 2   │ No           │ Yes          │ 817.18  │ 12106.1 │
# │ 3   │ No           │ No           │ 1073.55 │ 31767.1 │
# │ 4   │ No           │ No           │ 529.251 │ 35704.5 │
# │ 5   │ No           │ No           │ 785.656 │ 38463.5 │
# │ 6   │ No           │ Yes          │ 919.589 │ 7491.56 │

# %% [markdown]
# ## 前處理

# %%
isyes(x) = x == "Yes" ? 1.0 : 0.0

data[!, :DefaultNum] = isyes.(data[!, :Default])
data[!, :StudentNum] = isyes.(data[!, :Student])
first(data, 6)
# Out:
# 6×6 DataFrame. Omitted printing of 1 columns
# │ Row │ Default      │ Student      │ Balance │ Income  │ DefaultNum │
# │     │ Categorical… │ Categorical… │ Float64 │ Float64 │ Float64    │
# ├─────┼──────────────┼──────────────┼─────────┼─────────┼────────────┤
# │ 1   │ No           │ No           │ 729.526 │ 44361.6 │ 0.0        │
# │ 2   │ No           │ Yes          │ 817.18  │ 12106.1 │ 0.0        │
# │ 3   │ No           │ No           │ 1073.55 │ 31767.1 │ 0.0        │
# │ 4   │ No           │ No           │ 529.251 │ 35704.5 │ 0.0        │
# │ 5   │ No           │ No           │ 785.656 │ 38463.5 │ 0.0        │
# │ 6   │ No           │ Yes          │ 919.589 │ 7491.56 │ 0.0        │

# %% [markdown]
# ## 切分訓練資料及測試資料

# %%
indecies = MLDataUtils.shuffleobs(collect(1:nrow(data)))
train_ind, test_ind = MLDataUtils.splitobs(indecies, at=0.8);

# %%
train = data[train_ind, :]
test = data[test_ind, :]
# Out:
# 2000×6 DataFrame. Omitted printing of 1 columns
# │ Row  │ Default      │ Student      │ Balance │ Income  │ DefaultNum │
# │      │ Categorical… │ Categorical… │ Float64 │ Float64 │ Float64    │
# ├──────┼──────────────┼──────────────┼─────────┼─────────┼────────────┤
# │ 1    │ No           │ No           │ 215.068 │ 47815.6 │ 0.0        │
# │ 2    │ No           │ Yes          │ 561.782 │ 18470.3 │ 0.0        │
# │ 3    │ No           │ Yes          │ 810.542 │ 17975.2 │ 0.0        │
# │ 4    │ No           │ No           │ 371.865 │ 45949.9 │ 0.0        │
# │ 5    │ No           │ No           │ 748.211 │ 46981.9 │ 0.0        │
# │ 6    │ No           │ Yes          │ 953.809 │ 18241.7 │ 0.0        │
# │ 7    │ No           │ No           │ 474.769 │ 30799.9 │ 0.0        │
# │ 8    │ No           │ No           │ 1218.17 │ 43954.3 │ 0.0        │
# │ 9    │ No           │ No           │ 1185.74 │ 24265.4 │ 0.0        │
# │ 10   │ No           │ No           │ 1054.81 │ 52290.3 │ 0.0        │
# ⋮
# │ 1990 │ No           │ No           │ 1170.55 │ 52358.8 │ 0.0        │
# │ 1991 │ No           │ Yes          │ 1240.1  │ 20134.6 │ 0.0        │
# │ 1992 │ No           │ Yes          │ 734.459 │ 17619.5 │ 0.0        │
# │ 1993 │ No           │ No           │ 82.0885 │ 27357.6 │ 0.0        │
# │ 1994 │ No           │ Yes          │ 1503.08 │ 10600.4 │ 0.0        │
# │ 1995 │ No           │ No           │ 711.555 │ 52992.4 │ 0.0        │
# │ 1996 │ No           │ No           │ 989.636 │ 27318.9 │ 0.0        │
# │ 1997 │ Yes          │ Yes          │ 1543.1  │ 18304.7 │ 1.0        │
# │ 1998 │ No           │ No           │ 1204.95 │ 47167.9 │ 0.0        │
# │ 1999 │ No           │ No           │ 48.238  │ 37536.4 │ 0.0        │
# │ 2000 │ No           │ Yes          │ 948.151 │ 18107.4 │ 0.0        │

# %% [markdown]
# ## 羅吉斯迴歸模型

# %%
logreg = glm(@formula(DefaultNum ~ Balance + Income), train, Binomial(), LogitLink())
# Out:
# StatsModels.TableRegressionModel{GeneralizedLinearModel{GLM.GlmResp{Array{Float64,1},Binomial{Float64},LogitLink},GLM.DensePredChol{Float64,LinearAlgebra.Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# DefaultNum ~ 1 + Balance + Income
#
# Coefficients:
# ───────────────────────────────────────────────────────────────────────────────────────
#                  Estimate   Std. Error    z value  Pr(>|z|)     Lower 95%     Upper 95%
# ───────────────────────────────────────────────────────────────────────────────────────
# (Intercept)  -12.0072      0.510964     -23.4991     <1e-99  -13.0087      -11.0057
# Balance        0.00585283  0.000264349   22.1405     <1e-99    0.00533472    0.00637095
# Income         2.48859e-5  5.71854e-6     4.35179    <1e-4     1.36777e-5    3.6094e-5
# ───────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## 預測

# %%
pred = predict(logreg, test)
# Out:
# 2000-element Array{Union{Missing, Float64},1}:
#  7.059430451714988e-5
#  0.0002587170117680142
#  0.0010950222653631717
#  0.00016870120528019833
#  0.0015641554570231498
#  0.0025458662190168705
#  0.00021131425881050817
#  0.022234733589462135
#  0.011391893022292767
#  0.010641550525647735
#  0.008892319824454245
#  0.00031146573710391564
#  0.00535383006902918
#  ⋮
#  0.0968130668765975
#  0.020771843985335516
#  0.014090808715422122
#  0.0006956011065879726
#  1.948369195015641e-5
#  0.04991953737873571
#  0.0014659166239573802
#  0.003930109206832287
#  0.07445752398759423
#  0.022292277075815485
#  2.0589122815912936e-5
#  0.00245494413790733

# %% [markdown]
# ## 模型評估

# %%
error(x, y) = ((x > 0.5) ? 1.0 : 0.0) == y
accuracy(xs, ys) = mean(error.(xs, ys))
# Out:
# accuracy (generic function with 1 method)

# %%
accuracy(pred, test[!, :DefaultNum])
# Out:
# 0.974
