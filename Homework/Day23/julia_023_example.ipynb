# %% [markdown]
# # Julia 基礎圖表繪製: Plots 套件

# %% [markdown]
# 本範例需要使用到的套件有 Plots、StatsPlots，請在執行以下範例前先安裝。
#
# ```
# ] add Plots
# ] add StatsPlots
# ```

# %%
using Pkg
Pkg.add(["Plots","StatsPlots"])
# Out:
#    Updating registry at `C:\Users\ocean_chou\.julia\registries\General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#     Fetching: [
#     Fetching:
#     Fetching: [======================>
#     Fetching: [
# Fetching: [========================================>]  100.0 %   ]  89.6 %  ]  94.0 %
#   Resolving package versions...
#   Installed Plots ───────────── v1.1.2
#   Installed LibVPX_jll ──────── v1.8.1+1
#   Installed Clustering ──────── v0.14.0
#   Installed x265_jll ────────── v3.0.0+0
#   Installed FFMPEG_jll ──────── v4.1.0+2
#   Installed MultivariateStats ─ v0.7.0
#   Installed OpenSSL_jll ─────── v1.1.1+2
#   Installed x264_jll ────────── v2019.5.25+1
#   Installed RecipesPipeline ─── v0.1.6
#   Installed GeometryTypes ───── v0.8.2
#   Installed TableOperations ─── v0.2.1
#   Installed LAME_jll ────────── v3.100.0+0
#   Installed FFMPEG ──────────── v0.3.0
#   Installed NearestNeighbors ── v0.4.4
#   Installed PlotThemes ──────── v2.0.0
#   Installed libvorbis_jll ───── v1.3.6+2
#   Installed libfdk_aac_jll ──── v0.1.6+1
#   Installed Widgets ─────────── v0.6.2
#   Installed DataValues ──────── v0.4.13
#   Installed ColorSchemes ────── v3.9.0
#     Cloning [995b91a9-d308-5afd-9ec6-746e21dbc043] PlotUtils from https://github.com/JuliaPlots/PlotUtils.jl.git
#     Fetching: [
# Fetching: [========================================>]  100.0 %                      ]  42.3 %Fetching: [===================>                     ]  45.7 %                ]  60.0 %               ]  61.9 %>         ]  76.2 %  ]  93.0 %
#   Installed PlotUtils ───────── v1.0.0
#     Cloning [e7412a2a-1a6e-54c0-be00-318e2571c051] Ogg_jll from https://github.com/JuliaBinaryWrappers/Ogg_jll.jl.git
#     Fetching: [========================================>]  100.0 %
#   Installed Ogg_jll ─────────── v1.3.3+0
#     Cloning [28b8d3ca-fb5f-59d9-8090-bfdbd6d07a71] GR from https://github.com/jheinen/GR.jl.git
# Fetching: [========================================>]  100.0 %Fetching: [=================>                       ]  41.0 %=======================================> ]  95.4 %
#   Installed GR ──────────────── v0.48.0
#     Cloning [510215fc-4207-5dde-b226-833fc4488ee2] Observables from https://github.com/JuliaGizmos/Observables.jl.git
# Fetching: [========================================>]  100.0 %.0 %]  27.8 %49.9 %=============================>           ]  71.8 %]  72.3 % [======================================>  ]  94.2 %]  98.2 %
#   Installed Observables ─────── v0.3.1
#     Cloning [f3b207a7-027a-5e70-b257-86293d7955fd] StatsPlots from https://github.com/JuliaPlots/StatsPlots.jl.git
#     Fetching: [=====>                                   ]  10
# ching: [========================================>]  99.9 %]  22.0 %==============>                          ]  34.5 %4 %>                ]  58.9 %5 %          ]  74.9 %Fetching: [================================>        ]  77.6 %.6 %Fetching: [=======================================> ]  97.2 %
#   Installed StatsPlots ──────── v0.14.5
#     Cloning [91d4177d-7536-5919-b921-800302f37372] Opus_jll from https://github.com/JuliaBinaryWrappers/Opus_jll.jl.git
#     Fetching: [========================================>]  100.0 %
#   Installed Opus_jll ────────── v1.3.1+0
#     Cloning [0ac62f75-1d6f-5e53-bd7c-93b484bb37c0] libass_jll from https://github.com/JuliaBinaryWrappers/libass_jll.jl.git
#     Fetching: [========================================>]  100.0 %
#   Installed libass_jll ──────── v0.14.0+1
#    Updating `C:\Users\ocean_chou\.julia\environments\v1.4\Project.toml`
#   [91a5bcdd] + Plots v1.1.2
#   [f3b207a7] + StatsPlots v0.14.5
#    Updating `C:\Users\ocean_chou\.julia\environments\v1.4\Manifest.toml`
#   [aaaa29a8] + Clustering v0.14.0
#   [35d6a980] + ColorSchemes v3.9.0
#   [e7dc6d0d] + DataValues v0.4.13
#   [c87230d0] + FFMPEG v0.3.0
#   [b22a6f82] + FFMPEG_jll v4.1.0+2
#   [28b8d3ca] + GR v0.48.0
#   [4d00f742] + GeometryTypes v0.8.2
#   [c1c5ebd0] + LAME_jll v3.100.0+0
#   [dd192d2f] + LibVPX_jll v1.8.1+1
#   [6f286f6a] + MultivariateStats v0.7.0
#   [b8a86587] + NearestNeighbors v0.4.4
#   [510215fc] + Observables v0.3.1
#   [e7412a2a] + Ogg_jll v1.3.3+0
#   [458c3c95] + OpenSSL_jll v1.1.1+2
#   [91d4177d] + Opus_jll v1.3.1+0
#   [ccf2f8ad] + PlotThemes v2.0.0
#   [995b91a9] + PlotUtils v1.0.0
#   [91a5bcdd] + Plots v1.1.2
#   [01d81517] + RecipesPipeline v0.1.6
#   [f3b207a7] + StatsPlots v0.14.5
#   [ab02a1b2] + TableOperations v0.2.1
#   [cc8bc4a8] + Widgets v0.6.2
#   [0ac62f75] + libass_jll v0.14.0+1
#   [f638f0a6] + libfdk_aac_jll v0.1.6+1
#   [f27f6e37] + libvorbis_jll v1.3.6+2
#   [1270edf5] + x264_jll v2019.5.25+1
#   [dfaa095f] + x265_jll v3.0.0+0
#    Building GR ───→ `C:\Users\ocean_chou\.julia\packages\GR\yMV3y\deps\build.log`
#    Building Plots → `C:\Users\ocean_chou\.julia\packages\Plots\kgqnU\deps\build.log`

# %%
using RDatasets, Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1260

# %% [markdown]
# ## 圓餅圖

# %%
haireyecolor = dataset("datasets", "HairEyeColor")
haircolor = by(haireyecolor, :Hair, Freq=:Freq => sum)
p = pie(haircolor[!, :Hair], haircolor[!, :Freq]; size=(250, 200))

# %%
savefig(p, "pie.png")

# %% [markdown]
# ## 樹狀圖

# %% [markdown]
# ## Marginal histogram

# %%
using StatsPlots
gr()
# Out:
# ┌ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1260
# Plots.GRBackend()

# %%
n = 5000
x = randn(n)
y = -0.5x + randn(n)
p = marginalhist(x, y, fc=:plasma, bins=40)
# Out:
# ┌ Warning: Attribute alias `ylabel` detected in the plot recipe defined for the signature (::Type{Val{:marginalhist}}, ::AbstractPlot). To ensure expected behavior it is recommended to use the default attribute `yguide`.
# └ @ Plots C:\Users\ocean_chou\.julia\packages\Plots\kgqnU\src\pipeline.jl:15
# ┌ Warning: Attribute alias `xlabel` detected in the plot recipe defined for the signature (::Type{Val{:marginalhist}}, ::AbstractPlot). To ensure expected behavior it is recommended to use the default attribute `xguide`.
# └ @ Plots C:\Users\ocean_chou\.julia\packages\Plots\kgqnU\src\pipeline.jl:15
# ┌ Warning: Attribute alias `ylabel` detected in the plot recipe defined for the signature (::Type{Val{:marginalhist}}, ::AbstractPlot). To ensure expected behavior it is recommended to use the default attribute `yguide`.
# └ @ Plots C:\Users\ocean_chou\.julia\packages\Plots\kgqnU\src\pipeline.jl:15
# ┌ Warning: Attribute alias `xlabel` detected in the plot recipe defined for the signature (::Type{Val{:marginalhist}}, ::AbstractPlot). To ensure expected behavior it is recommended to use the default attribute `xguide`.
# └ @ Plots C:\Users\ocean_chou\.julia\packages\Plots\kgqnU\src\pipeline.jl:15

# %%
savefig(p, "marghist.png")

# %% [markdown]
# ## 3D 繪圖

# %%
n = 500
x = range(-8., stop=8., length=n)
y = range(-2., stop=2., length=n)
# Out:
# -2.0:0.008016032064128256:2.0

# %%
f(x,y) = x*exp(-(x-round(Int, x))^2-y^2)
# Out:
# f (generic function with 1 method)

# %%
p = plot(x, y, f, st=:surface)

# %%
savefig(p, "3d_function.png")

# %% [markdown]
# ## 3D 動畫

# %%
n = 500
x = range(-8., stop=8., length=n)
y = range(-2., stop=2., length=n)
f(x,y) = x*exp(-(x-round(Int, x))^2-y^2)
@gif for i in range(0, stop=2π, length=100)
    p = plot(x, y, f, st=:surface)
    plot!(p, camera=(15*cos(i), 40))
end
# Out:
# ┌ Info: Saved animation to
# │   fn = C:\Users\ocean_chou\Documents\GitHub\1st-JuliaMarathon\Homework\Day23\tmp.gif
# └ @ Plots C:\Users\ocean_chou\.julia\packages\Plots\kgqnU\src\animation.jl:102
# Plots.AnimatedGif("C:\\Users\\ocean_chou\\Documents\\GitHub\\1st-JuliaMarathon\\Homework\\Day23\\tmp.gif")

# %% [markdown]
# ## 動畫輸出

# %%
p = plot(1)
ani = @animate for i in range(0, stop=2π, length=100)
    p = plot(x, y, f, st=:surface)
    plot!(p, camera=(15*cos(i), 40))
end
gif(ani, "animate.gif", fps = 30)
# Out:
# ┌ Info: Saved animation to
# │   fn = C:\Users\ocean_chou\Documents\GitHub\1st-JuliaMarathon\Homework\Day23\animate.gif
# └ @ Plots C:\Users\ocean_chou\.julia\packages\Plots\kgqnU\src\animation.jl:102
# Plots.AnimatedGif("C:\\Users\\ocean_chou\\Documents\\GitHub\\1st-JuliaMarathon\\Homework\\Day23\\animate.gif")
